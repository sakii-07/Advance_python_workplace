# %%
import pandas as pd

# %%
s1 = pd.Series([1,3,4,5,7,8])
s1
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    7
# 5    8
# dtype: int64

# %%
student_info = {
    'sid' : [101,102,103,104,105],
    'sanme': ['sakshi','supriya','gayatri','divya','ragini'],
    'math': [None,67,89,78,90],
    'science' : [89,94,None,45,85]
}

# %%
student_info['result'].value_count()

# %%
# check correlation - data must be numeric 
student_info.corr(numeric_only=True)
student_info['Result'].map({"Pass":1})

# if column contain same value then correlation returns/gives none(NaN) value

# %%
x = student_info.iloc[:,:-1]
